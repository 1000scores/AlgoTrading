# %%
# %load_ext autoreload
# %autoreload 2
from backtest_model_admit import backtest_model_admit, backtest_model_class
import numpy as np
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
btc_1h_X, btc_1h_y, scores = backtest_model_admit(
    "BTCUSDT",
    "1h"
)

# %%
_, _ = backtest_model_admit(
    "BTCUSDT",
    "12h"
)

# %%
_, _ = backtest_model_admit(
    "BTCUSDT",
    "1d"
)
