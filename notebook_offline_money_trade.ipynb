# %%
# %load_ext autoreload
# %autoreload 2
from backtest_model_admit import backtest_model_admit
import numpy as np
from model_admit import ModelAdmit

# %%
btc_1h_X, btc_1h_y, scores = backtest_model_admit(
    ModelAdmit(thresh1=0.5, thresh2=0.5),
    "BTCUSDT",
    "1h"
)

# %%
btc_12h_X, btc_12h_y, scores = backtest_model_admit(
    ModelAdmit(thresh1=0.5, thresh2=0.5),
    "BTCUSDT",
    "12h"
)

# %%
btc_1d_X, btc_1d_y, scores = backtest_model_admit(
    ModelAdmit(thresh1=0.5, thresh2=0.5),
    "BTCUSDT",
    "1d"
)
